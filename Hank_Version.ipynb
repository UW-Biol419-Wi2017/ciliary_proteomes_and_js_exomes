# %%
# preliminaries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA

exome = pd.read_excel("JSexomes_2_output_1percentExAC_Corrected.xlsx")
exome.head
# Out:
# <bound method NDFrame.head of                                      File Name Chromosome   Position  \
# 0                      8073-1.final_output.txt          1     801943
# 1                      8079-3.final_output.txt          1     801943
# 2                      8168-3.final_output.txt          1     801943
# 3                      8179-3.final_output.txt          1     801943
# 4                      8212-3.final_output.txt          1     801943
# 5                      8212-4.final_output.txt          1     801943
# 6                      8276-3.final_output.txt          1     801943
# 7                      8358-3.final_output.txt          1     801943
# 8                      8385-3.final_output.txt          1     801943
# 9                      8440-3.final_output.txt          1     801943
# 10                     8441-3.final_output.txt          1     801943
# 11                     8073-1.final_output.txt          1     801995
# 12                   8084Trio.final_output.txt          1     801995
# 13                     8168-3.final_output.txt          1     801995
# 14                     8179-3.final_output.txt          1     801995
# 15                    8182Duo.final_output.txt          1     801995
# 16                   8187Trio.final_output.txt          1     801995
# 17                   8216Trio.final_output.txt          1     801995
# 18                   8234Trio.final_output.txt          1     801995
# 19                   8243Trio.final_output.txt          1     801995
# 20                     8276-3.final_output.txt          1     801995
# 21                 8330-3Trio.final_output.txt          1     801995
# 22                 8330-4Trio.final_output.txt          1     801995
# 23                     8358-3.final_output.txt          1     801995
# 24                     8385-3.final_output.txt          1     801995
# 25                   8419Trio.final_output.txt          1     801995
# 26                     8440-3.final_output.txt          1     801995
# 27                     8441-3.final_output.txt          1     801995
# 28                   8501Trio.final_output.txt          1     801995
# 29                     8073-1.final_output.txt          1     802006
# ...                                        ...        ...        ...
# 156093               8234Trio.final_output.txt          X  154020463
# 156094  JS_8505_UG.recalSNPs_Indels_output.txt          X  154051891
# 156095               8138Trio.final_output.txt          X  154114401
# 156096  JS_8505_UG.recalSNPs_Indels_output.txt          X  154133316
# 156097                 8440-3.final_output.txt          X  154255279
# 156098                 8073-1.final_output.txt          X  154301634
# 156099                 8079-3.final_output.txt          X  154301634
# 156100               8084Trio.final_output.txt          X  154301634
# 156101               8138Trio.final_output.txt          X  154301634
# 156102                 8168-3.final_output.txt          X  154301634
# 156103                8182Duo.final_output.txt          X  154301634
# 156104               8187Trio.final_output.txt          X  154301634
# 156105                 8212-3.final_output.txt          X  154301634
# 156106               8216Trio.final_output.txt          X  154301634
# 156107               8243Trio.final_output.txt          X  154301634
# 156108                 8276-3.final_output.txt          X  154301634
# 156109             8330-4Trio.final_output.txt          X  154301634
# 156110               8419Trio.final_output.txt          X  154301634
# 156111                 8441-3.final_output.txt          X  154301634
# 156112               8501Trio.final_output.txt          X  154301634
# 156113               8216Trio.final_output.txt          X  154319086
# 156114               8187Trio.final_output.txt          X  154444759
# 156115                 8276-3.final_output.txt          X  155003565
# 156116                 8276-3.final_output.txt          X  155003615
# 156117               8501Trio.final_output.txt          X  155171552
# 156118  JS_8505_UG.recalSNPs_Indels_output.txt          X  155230932
# 156119  JS_8505_UG.recalSNPs_Indels_output.txt          X  155230973
# 156120  JS_8505_UG.recalSNPs_Indels_output.txt          X  155231284
# 156121  JS_8505_UG.recalSNPs_Indels_output.txt          X  155235669
# 156122  JS_8505_UG.recalSNPs_Indels_output.txt          X  155235969
#
#        ReferenceAllele AlternateAllele                       Filter  \
# 0                    C               T   VQSRTrancheSNP99.00to99.90
# 1                    C               T   VQSRTrancheSNP99.00to99.90
# 2                    C               T   VQSRTrancheSNP99.00to99.90
# 3                    C               T   VQSRTrancheSNP99.00to99.90
# 4                    C               T   VQSRTrancheSNP99.00to99.90
# 5                    C               T   VQSRTrancheSNP99.00to99.90
# 6                    C               T   VQSRTrancheSNP99.00to99.90
# 7                    C               T   VQSRTrancheSNP99.00to99.90
# 8                    C               T   VQSRTrancheSNP99.00to99.90
# 9                    C               T   VQSRTrancheSNP99.00to99.90
# 10                   C               T   VQSRTrancheSNP99.00to99.90
# 11                   G               A   VQSRTrancheSNP99.00to99.90
# 12                   G               A   VQSRTrancheSNP99.00to99.90
# 13                   G               A   VQSRTrancheSNP99.00to99.90
# 14                   G               A   VQSRTrancheSNP99.00to99.90
# 15                   G               A   VQSRTrancheSNP99.00to99.90
# 16                   G               A   VQSRTrancheSNP99.00to99.90
# 17                   G               A   VQSRTrancheSNP99.00to99.90
# 18                   G               A   VQSRTrancheSNP99.00to99.90
# 19                   G               A   VQSRTrancheSNP99.00to99.90
# 20                   G               A   VQSRTrancheSNP99.00to99.90
# 21                   G               A   VQSRTrancheSNP99.00to99.90
# 22                   G               A   VQSRTrancheSNP99.00to99.90
# 23                   G               A   VQSRTrancheSNP99.00to99.90
# 24                   G               A   VQSRTrancheSNP99.00to99.90
# 25                   G               A   VQSRTrancheSNP99.00to99.90
# 26                   G               A   VQSRTrancheSNP99.00to99.90
# 27                   G               A   VQSRTrancheSNP99.00to99.90
# 28                   G               A   VQSRTrancheSNP99.00to99.90
# 29                   T               C  VQSRTrancheSNP99.90to100.00
# ...                ...             ...                          ...
# 156093               C               T                         PASS
# 156094               G               A                         PASS
# 156095               C               T   VQSRTrancheSNP99.00to99.90
# 156096               C               A                         PASS
# 156097               C               T                         PASS
# 156098               C               T  VQSRTrancheSNP99.90to100.00
# 156099               C               T  VQSRTrancheSNP99.90to100.00
# 156100               C               T  VQSRTrancheSNP99.90to100.00
# 156101               C               T  VQSRTrancheSNP99.90to100.00
# 156102               C               T  VQSRTrancheSNP99.90to100.00
# 156103               C               T  VQSRTrancheSNP99.90to100.00
# 156104               C               T  VQSRTrancheSNP99.90to100.00
# 156105               C               T  VQSRTrancheSNP99.90to100.00
# 156106               C               T  VQSRTrancheSNP99.90to100.00
# 156107               C               T  VQSRTrancheSNP99.90to100.00
# 156108               C               T  VQSRTrancheSNP99.90to100.00
# 156109               C               T  VQSRTrancheSNP99.90to100.00
# 156110               C               T  VQSRTrancheSNP99.90to100.00
# 156111               C               T  VQSRTrancheSNP99.90to100.00
# 156112               C               T  VQSRTrancheSNP99.90to100.00
# 156113               C               T   VQSRTrancheSNP99.00to99.90
# 156114               G               A                         PASS
# 156115               A               G                         PASS
# 156116               G               A   VQSRTrancheSNP99.00to99.90
# 156117               C               T   VQSRTrancheSNP99.00to99.90
# 156118               A               G                         PASS
# 156119               C               T                         PASS
# 156120               T               G                         PASS
# 156121               C               T                         PASS
# 156122               A               G   VQSRTrancheSNP99.00to99.90
#
#               GVSfunction     rsID AminoAcids Protein_Position     ...       \
# 0              intergenic  7516866       none              NaN     ...
# 1              intergenic  7516866       none              NaN     ...
# 2              intergenic  7516866       none              NaN     ...
# 3              intergenic  7516866       none              NaN     ...
# 4              intergenic  7516866       none              NaN     ...
# 5              intergenic  7516866       none              NaN     ...
# 6              intergenic  7516866       none              NaN     ...
# 7              intergenic  7516866       none              NaN     ...
# 8              intergenic  7516866       none              NaN     ...
# 9              intergenic  7516866       none              NaN     ...
# 10             intergenic  7516866       none              NaN     ...
# 11             intergenic  7553084       none              NaN     ...
# 12             intergenic  7553084       none              NaN     ...
# 13             intergenic  7553084       none              NaN     ...
# 14             intergenic  7553084       none              NaN     ...
# 15             intergenic  7553084       none              NaN     ...
# 16             intergenic  7553084       none              NaN     ...
# 17             intergenic  7553084       none              NaN     ...
# 18             intergenic  7553084       none              NaN     ...
# 19             intergenic  7553084       none              NaN     ...
# 20             intergenic  7553084       none              NaN     ...
# 21             intergenic  7553084       none              NaN     ...
# 22             intergenic  7553084       none              NaN     ...
# 23             intergenic  7553084       none              NaN     ...
# 24             intergenic  7553084       none              NaN     ...
# 25             intergenic  7553084       none              NaN     ...
# 26             intergenic  7553084       none              NaN     ...
# 27             intergenic  7553084       none              NaN     ...
# 28             intergenic  7553084       none              NaN     ...
# 29             intergenic  9700144       none              NaN     ...
# ...                   ...      ...        ...              ...     ...
# 156093           missense        0    ARG,GLN           67/467     ...
# 156094              utr-3  6643620       none              NaN     ...
# 156095             intron        0       none              NaN     ...
# 156096             intron        0       none              NaN     ...
# 156097  coding-synonymous        0       none           22/190     ...
# 156098             intron        0       none              NaN     ...
# 156099             intron        0       none              NaN     ...
# 156100             intron        0       none              NaN     ...
# 156101             intron        0       none              NaN     ...
# 156102             intron        0       none              NaN     ...
# 156103             intron        0       none              NaN     ...
# 156104             intron        0       none              NaN     ...
# 156105             intron        0       none              NaN     ...
# 156106             intron        0       none              NaN     ...
# 156107             intron        0       none              NaN     ...
# 156108             intron        0       none              NaN     ...
# 156109             intron        0       none              NaN     ...
# 156110             intron        0       none              NaN     ...
# 156111             intron        0       none              NaN     ...
# 156112             intron        0       none              NaN     ...
# 156113        stop-gained        0   GLN,stop          174/292     ...
# 156114              utr-5        0       none              NaN     ...
# 156115           missense        0    GLN,ARG           11/289     ...
# 156116           missense        0    VAL,MET           28/289     ...
# 156117  coding-synonymous        0       none          159/180     ...
# 156118             intron        0       none              NaN     ...
# 156119             intron        0       none              NaN     ...
# 156120             intron        0       none              NaN     ...
# 156121             intron        0       none              NaN     ...
# 156122             intron        0       none              NaN     ...
#
#        P1Alt P1Total P1_AltFreq P2Ref P2Alt P2Total P2_AltFreq  \
# 0          0       0       0.00     0     0       0       0.00
# 1          0       0       0.00     0     0       0       0.00
# 2          0       0       0.00     0     0       0       0.00
# 3          0       0       0.00     0     0       0       0.00
# 4          0       0       0.00     0     0       0       0.00
# 5          0       0       0.00     0     0       0       0.00
# 6          0       0       0.00     0     0       0       0.00
# 7          0       0       0.00     0     0       0       0.00
# 8          0       0       0.00     0     0       0       0.00
# 9          0       0       0.00     0     0       0       0.00
# 10         0       0       0.00     0     0       0       0.00
# 11         0       0       0.00     0     0       0       0.00
# 12        53      93       0.57    59    16      75       0.21
# 13         0       0       0.00     0     0       0       0.00
# 14         0       0       0.00     0     0       0       0.00
# 15        35     199       0.18     0     0       0       0.00
# 16        69     109       0.63    49     7      56       0.13
# 17        93     142       0.65    22    60      82       0.73
# 18        64      89       0.72    41     7      48       0.15
# 19        52      79       0.66    40     3      43       0.07
# 20         0       0       0.00     0     0       0       0.00
# 21         7      61       0.11    40    65     105       0.62
# 22         7      61       0.11    40    65     105       0.62
# 23         0       0       0.00     0     0       0       0.00
# 24         0       0       0.00     0     0       0       0.00
# 25        11      77       0.14    72    11      83       0.13
# 26         0       0       0.00     0     0       0       0.00
# 27         0       0       0.00     0     0       0       0.00
# 28        50      83       0.60    54     9      63       0.14
# 29         0       0       0.00     0     0       0       0.00
# ...      ...     ...        ...   ...   ...     ...        ...
# 156093     0      29       0.00    25    28      53       0.53
# 156094    10      21       0.48    31     0      31       0.00
# 156095     0       0       0.00    52     0      52       0.00
# 156096     2       3       0.67    13     2      15       0.13
# 156097     0       0       0.00     0     0       0       0.00
# 156098     0       0       0.00     0     0       0       0.00
# 156099     0       0       0.00     0     0       0       0.00
# 156100     2      18       0.11    48     5      53       0.09
# 156101     4      20       0.20    31     5      36       0.14
# 156102     0       0       0.00     0     0       0       0.00
# 156103     8      34       0.24     0     0       0       0.00
# 156104     5      25       0.20    35    15      50       0.30
# 156105     0       0       0.00     0     0       0       0.00
# 156106     1      34       0.03    47     7      54       0.13
# 156107     2      17       0.12    45     5      50       0.10
# 156108     0       0       0.00     0     0       0       0.00
# 156109     2       8       0.25    36     8      44       0.18
# 156110     3      25       0.12    34     6      40       0.15
# 156111     0       0       0.00     0     0       0       0.00
# 156112     2      15       0.13    35    14      49       0.29
# 156113     0      69       0.00   126     0     126       0.00
# 156114     0      47       0.00    76     0      76       0.00
# 156115     0       0       0.00     0     0       0       0.00
# 156116     0       0       0.00     0     0       0       0.00
# 156117     0     147       0.00   174     0     174       0.00
# 156118    22      66       0.33    61    44     105       0.42
# 156119    46     128       0.36   202     1     203       0.00
# 156120    23      37       0.62    53    36      89       0.40
# 156121    22      62       0.35   117     0     117       0.00
# 156122     4      13       0.31    20    23      43       0.53
#
#        Proband_Sample_Name js_cause localization
# 0             8073-1.final        0            0
# 1             8079-3.final        0            0
# 2             8168-3.final        0            0
# 3             8179-3.final        0            0
# 4             8212-3.final        0            0
# 5             8212-4.final        0            0
# 6             8276-3.final        0            0
# 7             8358-3.final        0            0
# 8             8385-3.final        0            0
# 9             8440-3.final        0            0
# 10            8441-3.final        0            0
# 11            8073-1.final        0            0
# 12          8084Trio.final        0            0
# 13            8168-3.final        0            0
# 14            8179-3.final        0            0
# 15           8182Duo.final        0            0
# 16          8187Trio.final        0            0
# 17          8216Trio.final        0            0
# 18          8234Trio.final        0            0
# 19          8243Trio.final        0            0
# 20            8276-3.final        0            0
# 21        8330-3Trio.final        0            0
# 22        8330-4Trio.final        0            0
# 23            8358-3.final        0            0
# 24            8385-3.final        0            0
# 25          8419Trio.final        0            0
# 26            8440-3.final        0            0
# 27            8441-3.final        0            0
# 28          8501Trio.final        0            0
# 29            8073-1.final        0            0
# ...                    ...      ...          ...
# 156093      8234Trio.final        0            3
# 156094                  JS        0            0
# 156095      8138Trio.final        0            0
# 156096                  JS        0            0
# 156097        8440-3.final        0            0
# 156098        8073-1.final        0            3
# 156099        8079-3.final        0            3
# 156100      8084Trio.final        0            3
# 156101      8138Trio.final        0            3
# 156102        8168-3.final        0            3
# 156103       8182Duo.final        0            3
# 156104      8187Trio.final        0            3
# 156105        8212-3.final        0            3
# 156106      8216Trio.final        0            3
# 156107      8243Trio.final        0            3
# 156108        8276-3.final        0            3
# 156109    8330-4Trio.final        0            3
# 156110      8419Trio.final        0            3
# 156111        8441-3.final        0            3
# 156112      8501Trio.final        0            3
# 156113      8216Trio.final        0            3
# 156114      8187Trio.final        0            3
# 156115        8276-3.final        0            0
# 156116        8276-3.final        0            0
# 156117      8501Trio.final        0            3
# 156118                  JS        0            0
# 156119                  JS        0            0
# 156120                  JS        0            0
# 156121                  JS        0            0
# 156122                  JS        0            0
#
# [156123 rows x 41 columns]>

# %%
exomeFiltered = exome.loc[:, ['CADD_score', 'AB', 'Dist2Splice', 'ExAC_Highest_MAF','localization', 'js_cause']].replace(['EXNF','CADDNF','unknown','NaN'],0).fillna(0)

# %%
exomeTest = exomeFiltered.loc[:,['CADD_score', 'AB', 'Dist2Splice', 'ExAC_Highest_MAF','localization']]

# %%
#PCA portion of the analysis
eigenVariant = PCA()
eigenVariant.fit(exomeTest)

plt.plot(np.cumsum(eigenVariant.explained_variance_ratio_))
plt.xlabel('Components')
plt.ylabel('Cumulative explained variance')
plt.title('Cumulative Explained Variance By Components')
np.cumsum(eigenVariant.explained_variance_ratio_)
# Out:
# array([ 0.9506877 ,  0.99999763,  1.        ,  1.        ,  1.        ])

# %%
variants_red = eigenVariant.transform(exomeTest)
plt.scatter(variants_red[:, 0].flatten(),variants_red[:, 1].flatten(), c = exome['js_cause'])
plt.title("PC1 by PC2")
plt.xlabel("PC1")
plt.ylabel("PC2")

# %%
#Classification portion of the analysis
model = LinearDiscriminantAnalysis()

X = variants_red
y = exome['js_cause']

model.fit(X, y)

predicted = model.predict(X)

print(predicted)

for JS in set(predicted):
    plt.plot(X[predicted==JS,0], X[predicted==JS,1], 'o')
# Out:
# C:\Users\hankc\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:387: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# [0 0 0 ..., 0 0 0]

# %%
X_new = model.transform(X)

for JS in set(predicted):
    plt.hist(X_new[predicted==JS], bins=np.linspace(-5,5,20))

# %%
sns.pairplot(exomeFiltered, hue='js_cause')

# %%
#If other exome file is loaded
exome_2 = pd.read_excel("JSexomes_2_output_1percentExAC_Corrected.xlsx")
exome_1 = pd.read_table("JSexomes_1_1percentExAC_reAnn138_output_new_Corrected.txt")
exome = pd.concat([exome_1, exome_2])
exomeTest = exome.loc[:, ['Gene', 'CADD_score', 'AB', 'Chromosome', 'Dist2Splice', 'ExAC_Highest_MAF','localization']].replace('EXNF',0)
