# %%
#Analysis with NA values deleted and the 0 value for localization included

# preliminaries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA

exome = pd.read_excel("HC-JSexomes_2_output_1percentExAC_Corrected.xlsx")
exome.head
# Out:
# <bound method NDFrame.head of                                      File Name Chromosome   Position  \
# 0                    8187Trio.final_output.txt          1     871213
# 1                    8187Trio.final_output.txt          1     871213
# 2       JS_8505_UG.recalSNPs_Indels_output.txt          1     874912
# 3                    8084Trio.final_output.txt          1     878743
# 4       JS_8505_UG.recalSNPs_Indels_output.txt          1     882033
# 5       JS_8505_UG.recalSNPs_Indels_output.txt          1     884091
# 6       JS_8505_UG.recalSNPs_Indels_output.txt          1     884101
# 7                      8079-3.final_output.txt          1     891297
# 8                    8084Trio.final_output.txt          1     891297
# 9                    8138Trio.final_output.txt          1     891297
# 10                    8182Duo.final_output.txt          1     891297
# 11                   8187Trio.final_output.txt          1     891297
# 12                   8216Trio.final_output.txt          1     891297
# 13                   8234Trio.final_output.txt          1     891297
# 14                   8243Trio.final_output.txt          1     891297
# 15                 8330-3Trio.final_output.txt          1     891297
# 16                 8330-4Trio.final_output.txt          1     891297
# 17                   8419Trio.final_output.txt          1     891297
# 18                   8501Trio.final_output.txt          1     891297
# 19      JS_8505_UG.recalSNPs_Indels_output.txt          1     900009
# 20                     8358-3.final_output.txt          1     906122
# 21                 8330-3Trio.final_output.txt          1     907768
# 22                     8073-1.final_output.txt          1     909680
# 23                 8330-3Trio.final_output.txt          1     934610
# 24                     8385-3.final_output.txt          1     934620
# 25      JS_8505_UG.recalSNPs_Indels_output.txt          1     957898
# 26      JS_8505_UG.recalSNPs_Indels_output.txt          1     977133
# 27                   8138Trio.final_output.txt          1     977406
# 28                   8501Trio.final_output.txt          1     978668
# 29                     8079-3.final_output.txt          1     981869
# ...                                        ...        ...        ...
# 100343               8234Trio.final_output.txt          X  154020463
# 100344  JS_8505_UG.recalSNPs_Indels_output.txt          X  154051891
# 100345               8138Trio.final_output.txt          X  154114401
# 100346  JS_8505_UG.recalSNPs_Indels_output.txt          X  154133316
# 100347                 8440-3.final_output.txt          X  154255279
# 100348                 8073-1.final_output.txt          X  154301634
# 100349                 8079-3.final_output.txt          X  154301634
# 100350               8084Trio.final_output.txt          X  154301634
# 100351               8138Trio.final_output.txt          X  154301634
# 100352                 8168-3.final_output.txt          X  154301634
# 100353                8182Duo.final_output.txt          X  154301634
# 100354               8187Trio.final_output.txt          X  154301634
# 100355                 8212-3.final_output.txt          X  154301634
# 100356               8216Trio.final_output.txt          X  154301634
# 100357               8243Trio.final_output.txt          X  154301634
# 100358                 8276-3.final_output.txt          X  154301634
# 100359             8330-4Trio.final_output.txt          X  154301634
# 100360               8419Trio.final_output.txt          X  154301634
# 100361                 8441-3.final_output.txt          X  154301634
# 100362               8501Trio.final_output.txt          X  154301634
# 100363               8216Trio.final_output.txt          X  154319086
# 100364               8187Trio.final_output.txt          X  154444759
# 100365                 8276-3.final_output.txt          X  155003565
# 100366                 8276-3.final_output.txt          X  155003615
# 100367               8501Trio.final_output.txt          X  155171552
# 100368  JS_8505_UG.recalSNPs_Indels_output.txt          X  155230932
# 100369  JS_8505_UG.recalSNPs_Indels_output.txt          X  155230973
# 100370  JS_8505_UG.recalSNPs_Indels_output.txt          X  155231284
# 100371  JS_8505_UG.recalSNPs_Indels_output.txt          X  155235669
# 100372  JS_8505_UG.recalSNPs_Indels_output.txt          X  155235969
#
#        ReferenceAllele AlternateAllele                       Filter  \
# 0                    C               G   VQSRTrancheSNP99.00to99.90
# 1                    C               G   VQSRTrancheSNP99.00to99.90
# 2                    T               C                         PASS
# 3                    G               C                         PASS
# 4                    G               A                         PASS
# 5                    C               G  VQSRTrancheSNP99.90to100.00
# 6                    A               C  VQSRTrancheSNP99.90to100.00
# 7                    T               C  VQSRTrancheSNP99.90to100.00
# 8                    T               C  VQSRTrancheSNP99.90to100.00
# 9                    T               C  VQSRTrancheSNP99.90to100.00
# 10                   T               C  VQSRTrancheSNP99.90to100.00
# 11                   T               C  VQSRTrancheSNP99.90to100.00
# 12                   T               C  VQSRTrancheSNP99.90to100.00
# 13                   T               C  VQSRTrancheSNP99.90to100.00
# 14                   T               C  VQSRTrancheSNP99.90to100.00
# 15                   T               C  VQSRTrancheSNP99.90to100.00
# 16                   T               C  VQSRTrancheSNP99.90to100.00
# 17                   T               C  VQSRTrancheSNP99.90to100.00
# 18                   T               C  VQSRTrancheSNP99.90to100.00
# 19                   C               G                         PASS
# 20                   C               T                         PASS
# 21                   G               A                         PASS
# 22                   C               T                         PASS
# 23                   T               C                         PASS
# 24                   G               A   VQSRTrancheSNP99.00to99.90
# 25                   G               T                         PASS
# 26                   G               A  VQSRTrancheSNP99.90to100.00
# 27                   C               T                         PASS
# 28                   G               A                         PASS
# 29                   G               C  VQSRTrancheSNP99.90to100.00
# ...                ...             ...                          ...
# 100343               C               T                         PASS
# 100344               G               A                         PASS
# 100345               C               T   VQSRTrancheSNP99.00to99.90
# 100346               C               A                         PASS
# 100347               C               T                         PASS
# 100348               C               T  VQSRTrancheSNP99.90to100.00
# 100349               C               T  VQSRTrancheSNP99.90to100.00
# 100350               C               T  VQSRTrancheSNP99.90to100.00
# 100351               C               T  VQSRTrancheSNP99.90to100.00
# 100352               C               T  VQSRTrancheSNP99.90to100.00
# 100353               C               T  VQSRTrancheSNP99.90to100.00
# 100354               C               T  VQSRTrancheSNP99.90to100.00
# 100355               C               T  VQSRTrancheSNP99.90to100.00
# 100356               C               T  VQSRTrancheSNP99.90to100.00
# 100357               C               T  VQSRTrancheSNP99.90to100.00
# 100358               C               T  VQSRTrancheSNP99.90to100.00
# 100359               C               T  VQSRTrancheSNP99.90to100.00
# 100360               C               T  VQSRTrancheSNP99.90to100.00
# 100361               C               T  VQSRTrancheSNP99.90to100.00
# 100362               C               T  VQSRTrancheSNP99.90to100.00
# 100363               C               T   VQSRTrancheSNP99.00to99.90
# 100364               G               A                         PASS
# 100365               A               G                         PASS
# 100366               G               A   VQSRTrancheSNP99.00to99.90
# 100367               C               T   VQSRTrancheSNP99.00to99.90
# 100368               A               G                         PASS
# 100369               C               T                         PASS
# 100370               T               G                         PASS
# 100371               C               T                         PASS
# 100372               A               G   VQSRTrancheSNP99.00to99.90
#
#               GVSfunction       rsID AminoAcids Protein_Position     ...       \
# 0       coding-synonymous  144490434       none          123/682     ...
# 1                missense  144490434    PRO,ALA          123/682     ...
# 2                  intron          0       none              NaN     ...
# 3                missense          0    GLY,ARG          559/682     ...
# 4                  intron    2272756       none              NaN     ...
# 5                  intron    7522415       none              NaN     ...
# 6                  intron    4970455       none              NaN     ...
# 7                  intron          0       none              NaN     ...
# 8                  intron          0       none              NaN     ...
# 9                  intron          0       none              NaN     ...
# 10                 intron          0       none              NaN     ...
# 11                 intron          0       none              NaN     ...
# 12                 intron          0       none              NaN     ...
# 13                 intron          0       none              NaN     ...
# 14                 intron          0       none              NaN     ...
# 15                 intron          0       none              NaN     ...
# 16                 intron          0       none              NaN     ...
# 17                 intron          0       none              NaN     ...
# 18                 intron          0       none              NaN     ...
# 19                 intron    6704181       none              NaN     ...
# 20      coding-synonymous   41285812       none          156/577     ...
# 21      coding-synonymous          0       none          334/577     ...
# 22                 intron  199980201       none              NaN     ...
# 23      coding-synonymous          0       none          191/248     ...
# 24               missense          0    ALA,VAL          188/248     ...
# 25                 intron    2799064       none              NaN     ...
# 26                 intron   61766305       none              NaN     ...
# 27      coding-synonymous          0       none         416/2046     ...
# 28      coding-synonymous  147346337       none         478/2046     ...
# 29               missense          0    GLY,ARG        1002/2046     ...
# ...                   ...        ...        ...              ...     ...
# 100343           missense          0    ARG,GLN           67/467     ...
# 100344              utr-3    6643620       none              NaN     ...
# 100345             intron          0       none              NaN     ...
# 100346             intron          0       none              NaN     ...
# 100347  coding-synonymous          0       none           22/190     ...
# 100348             intron          0       none              NaN     ...
# 100349             intron          0       none              NaN     ...
# 100350             intron          0       none              NaN     ...
# 100351             intron          0       none              NaN     ...
# 100352             intron          0       none              NaN     ...
# 100353             intron          0       none              NaN     ...
# 100354             intron          0       none              NaN     ...
# 100355             intron          0       none              NaN     ...
# 100356             intron          0       none              NaN     ...
# 100357             intron          0       none              NaN     ...
# 100358             intron          0       none              NaN     ...
# 100359             intron          0       none              NaN     ...
# 100360             intron          0       none              NaN     ...
# 100361             intron          0       none              NaN     ...
# 100362             intron          0       none              NaN     ...
# 100363        stop-gained          0   GLN,stop          174/292     ...
# 100364              utr-5          0       none              NaN     ...
# 100365           missense          0    GLN,ARG           11/289     ...
# 100366           missense          0    VAL,MET           28/289     ...
# 100367  coding-synonymous          0       none          159/180     ...
# 100368             intron          0       none              NaN     ...
# 100369             intron          0       none              NaN     ...
# 100370             intron          0       none              NaN     ...
# 100371             intron          0       none              NaN     ...
# 100372             intron          0       none              NaN     ...
#
#         P1Alt P1Total  P1_AltFreq  P2Ref P2Alt  P2Total  P2_AltFreq  \
# 0           0      71        0.00     18    22       40        0.55
# 1           0      71        0.00     18    22       40        0.55
# 2           9      16        0.56     23     0       23        0.00
# 3           0      17        0.00      9    12       21        0.57
# 4           0      31        0.00     40    21       61        0.34
# 5          61     182        0.34    243   179      422        0.42
# 6         101     162        0.62    179   203      382        0.53
# 7           0       0        0.00      0     0        0        0.00
# 8          13      49        0.27     49    12       61        0.20
# 9          11      49        0.22     29     5       34        0.15
# 10         18     114        0.16      0     0        0        0.00
# 11          9      51        0.18     27     7       34        0.21
# 12         16      75        0.21     37     6       43        0.14
# 13          9      43        0.21     37    12       49        0.24
# 14          7      39        0.18     37    11       48        0.23
# 15          5      35        0.14     38    11       49        0.22
# 16          5      35        0.14     38    11       49        0.22
# 17         11      57        0.19     40     8       48        0.17
# 18          8      36        0.22     41    11       52        0.21
# 19          0       0        0.00      2     6        8        0.75
# 20          0       0        0.00      0     0        0        0.00
# 21          7      21        0.33     44     0       44        0.00
# 22          0       0        0.00      0     0        0        0.00
# 23          2       9        0.22      6     0        6        0.00
# 24          0       0        0.00      0     0        0        0.00
# 25         19      31        0.61     32    36       68        0.53
# 26          3      15        0.20     71    21       92        0.23
# 27         16      32        0.50     19     0       19        0.00
# 28         32      53        0.60     65     0       65        0.00
# 29          0       0        0.00      0     0        0        0.00
# ...       ...     ...         ...    ...   ...      ...         ...
# 100343      0      29        0.00     25    28       53        0.53
# 100344     10      21        0.48     31     0       31        0.00
# 100345      0       0        0.00     52     0       52        0.00
# 100346      2       3        0.67     13     2       15        0.13
# 100347      0       0        0.00      0     0        0        0.00
# 100348      0       0        0.00      0     0        0        0.00
# 100349      0       0        0.00      0     0        0        0.00
# 100350      2      18        0.11     48     5       53        0.09
# 100351      4      20        0.20     31     5       36        0.14
# 100352      0       0        0.00      0     0        0        0.00
# 100353      8      34        0.24      0     0        0        0.00
# 100354      5      25        0.20     35    15       50        0.30
# 100355      0       0        0.00      0     0        0        0.00
# 100356      1      34        0.03     47     7       54        0.13
# 100357      2      17        0.12     45     5       50        0.10
# 100358      0       0        0.00      0     0        0        0.00
# 100359      2       8        0.25     36     8       44        0.18
# 100360      3      25        0.12     34     6       40        0.15
# 100361      0       0        0.00      0     0        0        0.00
# 100362      2      15        0.13     35    14       49        0.29
# 100363      0      69        0.00    126     0      126        0.00
# 100364      0      47        0.00     76     0       76        0.00
# 100365      0       0        0.00      0     0        0        0.00
# 100366      0       0        0.00      0     0        0        0.00
# 100367      0     147        0.00    174     0      174        0.00
# 100368     22      66        0.33     61    44      105        0.42
# 100369     46     128        0.36    202     1      203        0.00
# 100370     23      37        0.62     53    36       89        0.40
# 100371     22      62        0.35    117     0      117        0.00
# 100372      4      13        0.31     20    23       43        0.53
#
#         Proband_Sample_Name js_cause localization
# 0            8187Trio.final        0            0
# 1            8187Trio.final        0            0
# 2                        JS        0            0
# 3            8084Trio.final        0            0
# 4                        JS        0            0
# 5                        JS        0            0
# 6                        JS        0            0
# 7              8079-3.final        0            0
# 8            8084Trio.final        0            0
# 9            8138Trio.final        0            0
# 10            8182Duo.final        0            0
# 11           8187Trio.final        0            0
# 12           8216Trio.final        0            0
# 13           8234Trio.final        0            0
# 14           8243Trio.final        0            0
# 15         8330-3Trio.final        0            0
# 16         8330-4Trio.final        0            0
# 17           8419Trio.final        0            0
# 18           8501Trio.final        0            0
# 19                       JS        0            0
# 20             8358-3.final        0            0
# 21         8330-3Trio.final        0            0
# 22             8073-1.final        0            0
# 23         8330-3Trio.final        0            0
# 24             8385-3.final        0            0
# 25                       JS        0            3
# 26                       JS        0            3
# 27           8138Trio.final        0            3
# 28           8501Trio.final        0            3
# 29             8079-3.final        0            3
# ...                     ...      ...          ...
# 100343       8234Trio.final        0            3
# 100344                   JS        0            0
# 100345       8138Trio.final        0            0
# 100346                   JS        0            0
# 100347         8440-3.final        0            0
# 100348         8073-1.final        0            3
# 100349         8079-3.final        0            3
# 100350       8084Trio.final        0            3
# 100351       8138Trio.final        0            3
# 100352         8168-3.final        0            3
# 100353        8182Duo.final        0            3
# 100354       8187Trio.final        0            3
# 100355         8212-3.final        0            3
# 100356       8216Trio.final        0            3
# 100357       8243Trio.final        0            3
# 100358         8276-3.final        0            3
# 100359     8330-4Trio.final        0            3
# 100360       8419Trio.final        0            3
# 100361         8441-3.final        0            3
# 100362       8501Trio.final        0            3
# 100363       8216Trio.final        0            3
# 100364       8187Trio.final        0            3
# 100365         8276-3.final        0            0
# 100366         8276-3.final        0            0
# 100367       8501Trio.final        0            3
# 100368                   JS        0            0
# 100369                   JS        0            0
# 100370                   JS        0            0
# 100371                   JS        0            0
# 100372                   JS        0            0
#
# [100373 rows x 41 columns]>

# %%
exomeFiltered = exome.loc[:, ['GERP','CADD_PHRED_score', 'AB', 'P1_AltFreq', 'P2_AltFreq' ,'localization', 'js_cause']]

# %%
exome.shape
# Out:
# (100373, 41)

# %%
exomeTest = exomeFiltered.loc[:,['GERP','CADD_PHRED_score', 'AB', 'P1_AltFreq', 'P2_AltFreq']]

# %%
#PCA portion of the analysis
eigenVariant = PCA()
eigenVariant.fit(exomeTest)

plt.plot(np.cumsum(eigenVariant.explained_variance_ratio_))
plt.xlabel('Components')
plt.ylabel('Cumulative explained variance')
plt.title('Cumulative Explained Variance By Components')
np.cumsum(eigenVariant.explained_variance_ratio_)
# Out:
# array([ 0.89455357,  0.99855776,  0.99931856,  0.99968311,  1.        ])

# %%
#PC plot colored by js_cause
variants_red = eigenVariant.transform(exomeTest)
plt.scatter(variants_red[:, 0].flatten(),variants_red[:, 1].flatten(), c=exome['js_cause'])
plt.title("PC1 by PC2")
plt.xlabel("PC1")
plt.ylabel("PC2")

# %%
#PC plot colored by localization
variants_red = eigenVariant.transform(exomeTest)
exomeColor = exome['localization'].replace([0,1,2,3],['blue', 'red','green','black'])
plt.scatter(variants_red[:, 0].flatten(),variants_red[:, 1].flatten(), c= exomeColor)
plt.title("PC1 by PC2")
plt.xlabel("PC1")
plt.ylabel("PC2")

# %%
#PC plot with only JS causative variants
variants_red = eigenVariant.transform(exomeTest)
plt.scatter(variants_red[:, 0].flatten(),variants_red[:, 1].flatten(), exome['js_cause']==1)
plt.title("PC1 by PC2")
plt.xlabel("PC1")
plt.ylabel("PC2")

# %%
model = LinearDiscriminantAnalysis()

X = variants_red[:,[0,1]]
y = exome['js_cause']

model.fit(X, y)

predicted = model.predict(X)

print(predicted)

for JS in set(predicted):
    plt.plot(X[predicted==JS,0], X[predicted==JS,1], 'o')
# Out:
# [0 0 0 ..., 0 0 0]

# %%
sns.pairplot(exomeTest)
