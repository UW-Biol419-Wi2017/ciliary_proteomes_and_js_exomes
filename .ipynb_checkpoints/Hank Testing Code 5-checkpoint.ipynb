# %%
#Same analysis done in Testing Code 4. Except with binary data in localization column and also logistic regression. 
import os
print(os.getcwd())
print("\n", os.listdir()) # list items in current working directory after "\n" return key
# Out:
# C:\Users\hankc\OneDrive\Documents\GitHub\ciliary_proteomes_and_js_exomes
#
#  ['.git', '.ipynb_checkpoints', 'Cellbody_and_cilia+_fraction.xlsx', 'cellBody_only.xlsx', 'CellBody_only_Repaired.xlsx', 'Cheng_Grout_final_project.ipynb', 'Cilia_only_fraction.xlsx', 'Experimental_Copy.ipynb', 'Hank Testing Classifiers Testing.ipynb', 'Hank Testing Code 2.ipynb', 'Hank Testing Code 3.ipynb', 'Hank Testing Code 4.ipynb', 'Hank Testing Code 5.ipynb', 'Hank Testing Code 6.ipynb', 'Hank Testing Code 7-1000.ipynb', 'Hank Testing Code 7.ipynb', 'Hank Testing Code 8-100.ipynb', 'Hank Testing Code 8-1000.ipynb', 'Hank Testing Code 8.ipynb', 'Hank_Testing_Code.ipynb', 'Hank_Version.ipynb', 'HC-JSexomes_2_output_1percentExAC_Corrected.xlsx', 'HC1_js_exomes_2_MG_170307.xlsx', 'HC2_js_exomes_2_MG_170307.xlsx', 'HC3_1000_js_exomes_2_MG_170307.xlsx', 'HC3_1000_loc_js_exomes_2_MG_170307.xlsx', 'HC3_100_js_exomes_2_MG_170307.xlsx', 'HC3_js_exomes_2_MG_170307.xlsx', 'HC_js_exomes_2_MG_170307.xlsx', 'JSexomes_1_1percentExAC_reAnn138_output_new.txt', 'JSexomes_2_output_1percentExAC.xlsx', 'JSexomes_2_output_1percentExAC_Corrected - Copy.xlsx', 'JSexomes_2_output_1percentExAC_Corrected.xlsx', 'js_exomes_2_MG_170307.xlsx', 'js_genes.txt', 'README.md', 'Testing Code']

# %%
# NA values removed and 0 values for localization column removed.

# preliminaries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA

exome = pd.read_excel("HC3_js_exomes_2_MG_170307.xlsx")
exome.head
# Out:
# <bound method NDFrame.head of                          Chromosome   Position ReferenceAllele  \
# 0      8084Trio.final_output.txt 10  101510116               C
# 1      8084Trio.final_output.txt 10  103717493               T
# 2      8084Trio.final_output.txt 10  104263946               A
# 3      8084Trio.final_output.txt 10  104263949               G
# 4      8084Trio.final_output.txt 10  104263963               T
# 5      8084Trio.final_output.txt 10  104679140               C
# 6      8084Trio.final_output.txt 10  111893349               C
# 7      8084Trio.final_output.txt 10  112361765               G
# 8      8084Trio.final_output.txt 10  117823963               C
# 9      8084Trio.final_output.txt 10  118738802               C
# 10     8084Trio.final_output.txt 10  118738802               C
# 11     8084Trio.final_output.txt 10  120938290               C
# 12     8084Trio.final_output.txt 10  121691666               G
# 13     8084Trio.final_output.txt 10   12272989               A
# 14     8084Trio.final_output.txt 10  123343270               C
# 15     8084Trio.final_output.txt 10  123343272               G
# 16     8084Trio.final_output.txt 10  123343273               C
# 17     8084Trio.final_output.txt 10  124895635               A
# 18     8084Trio.final_output.txt 10  128864133               A
# 19     8084Trio.final_output.txt 10  128864601               G
# 20     8084Trio.final_output.txt 10   16528528               C
# 21     8084Trio.final_output.txt 10   16824091               G
# 22     8084Trio.final_output.txt 10   16824091               G
# 23     8084Trio.final_output.txt 10   16824096               G
# 24     8084Trio.final_output.txt 10   28409544               C
# 25     8084Trio.final_output.txt 10   35314130               T
# 26     8084Trio.final_output.txt 10   60148569               C
# 27     8084Trio.final_output.txt 10   60148569               C
# 28     8084Trio.final_output.txt 10   61840384               G
# 29     8084Trio.final_output.txt 10   61840385               G
# ...                             ...        ...             ...
# 10183   8501Trio.final_output.txt X  154301634               C
# 10184   8501Trio.final_output.txt X  155171552               C
# 10185   8501Trio.final_output.txt X  155171552               C
# 10186   8501Trio.final_output.txt X   24833100               G
# 10187   8501Trio.final_output.txt X   38145714               T
# 10188   8501Trio.final_output.txt X   38145718               T
# 10189   8501Trio.final_output.txt X   38145721               T
# 10190   8501Trio.final_output.txt X   38145735               T
# 10191   8501Trio.final_output.txt X   38145739               T
# 10192   8501Trio.final_output.txt X   38145819               T
# 10193   8501Trio.final_output.txt X   40954541               A
# 10194   8501Trio.final_output.txt X   41383297               G
# 10195   8501Trio.final_output.txt X   51637757               T
# 10196   8501Trio.final_output.txt X   51637757               T
# 10197   8501Trio.final_output.txt X   51637781               T
# 10198   8501Trio.final_output.txt X   51637781               T
# 10199   8501Trio.final_output.txt X   53263989               A
# 10200   8501Trio.final_output.txt X   53263989               A
# 10201   8501Trio.final_output.txt X   53263992               T
# 10202   8501Trio.final_output.txt X   53263992               T
# 10203   8501Trio.final_output.txt X   53264307               C
# 10204   8501Trio.final_output.txt X   53264307               C
# 10205   8501Trio.final_output.txt X   53264313               T
# 10206   8501Trio.final_output.txt X   53264313               T
# 10207   8501Trio.final_output.txt X   54324734               T
# 10208   8501Trio.final_output.txt X   54475305               G
# 10209   8501Trio.final_output.txt X   54497147               T
# 10210   8501Trio.final_output.txt X   54497160               C
# 10211   8501Trio.final_output.txt X   85236824               T
# 10212   8501Trio.final_output.txt X   96171436               G
#
#       AlternateAllele                       Filter         GVSfunction  \
# 0                   T  VQSRTrancheSNP99.90to100.00              intron
# 1                   A  VQSRTrancheSNP99.90to100.00  intron-near-splice
# 2                   C  VQSRTrancheSNP99.90to100.00            missense
# 3                   C  VQSRTrancheSNP99.90to100.00            missense
# 4                   C  VQSRTrancheSNP99.90to100.00          synonymous
# 5                   T                         PASS          synonymous
# 6                   A   VQSRTrancheSNP99.00to99.90            missense
# 7                   A                         PASS          synonymous
# 8                   G                         PASS          synonymous
# 9                   A                         PASS            missense
# 10                  A                         PASS         5-prime-UTR
# 11                  T                         PASS            missense
# 12                  T                         PASS            missense
# 13                  G                         PASS          synonymous
# 14                  A  VQSRTrancheSNP99.90to100.00              intron
# 15                  A  VQSRTrancheSNP99.90to100.00              intron
# 16                  A  VQSRTrancheSNP99.90to100.00              intron
# 17                  C  VQSRTrancheSNP99.90to100.00          synonymous
# 18                  G                         PASS              intron
# 19                  T                         PASS              intron
# 20                  T                         PASS            missense
# 21                  A  VQSRTrancheSNP99.90to100.00  intron-near-splice
# 22                  A  VQSRTrancheSNP99.90to100.00              intron
# 23                  A  VQSRTrancheSNP99.90to100.00              intron
# 24                  T                         PASS          synonymous
# 25                  A  VQSRTrancheSNP99.90to100.00  intron-near-splice
# 26                  A  VQSRTrancheSNP99.90to100.00            missense
# 27                  A  VQSRTrancheSNP99.90to100.00     non-coding-exon
# 28                  A  VQSRTrancheSNP99.90to100.00  intron-near-splice
# 29                  A  VQSRTrancheSNP99.90to100.00              intron
# ...               ...                          ...                 ...
# 10183               T  VQSRTrancheSNP99.90to100.00              intron
# 10184               T   VQSRTrancheSNP99.00to99.90          synonymous
# 10185               T   VQSRTrancheSNP99.00to99.90     non-coding-exon
# 10186               T  VQSRTrancheSNP99.90to100.00            missense
# 10187               C  VQSRTrancheSNP99.90to100.00              intron
# 10188               C   VQSRTrancheSNP99.00to99.90              intron
# 10189               C  VQSRTrancheSNP99.90to100.00              intron
# 10190               C  VQSRTrancheSNP99.90to100.00              intron
# 10191               C  VQSRTrancheSNP99.90to100.00              intron
# 10192               C   VQSRTrancheSNP99.00to99.90              intron
# 10193               G   VQSRTrancheSNP99.00to99.90              intron
# 10194               A  VQSRTrancheSNP99.90to100.00              intron
# 10195               C                         PASS              intron
# 10196               C                         PASS            missense
# 10197               C                         PASS              intron
# 10198               C                         PASS            missense
# 10199               G                         PASS          synonymous
# 10200               G                         PASS         3-prime-UTR
# 10201               G                         PASS          synonymous
# 10202               G                         PASS         3-prime-UTR
# 10203               G  VQSRTrancheSNP99.90to100.00          synonymous
# 10204               G  VQSRTrancheSNP99.90to100.00         3-prime-UTR
# 10205               G  VQSRTrancheSNP99.90to100.00          synonymous
# 10206               G  VQSRTrancheSNP99.90to100.00         3-prime-UTR
# 10207               C                         PASS          synonymous
# 10208               A                         PASS          synonymous
# 10209               G                         PASS          synonymous
# 10210               G   VQSRTrancheSNP99.00to99.90            missense
# 10211               A                         PASS              intron
# 10212               T  VQSRTrancheSNP99.90to100.00     splice-acceptor
#
#             rsID AminoAcids Protein_Position  CDNA_Position     ...       \
# 0              0       none              NaN            NaN     ...
# 1              0       none              NaN            NaN     ...
# 2              0    THR,PRO           13/434           37.0     ...
# 3              0    ALA,PRO           14/434           40.0     ...
# 4              0        PRO           18/434           54.0     ...
# 5      140279763        TYR          301/876          903.0     ...
# 6      149355298    ASN,LYS          666/675         1998.0     ...
# 7      147463420        LYS         978/1218         2934.0     ...
# 8       75841238        LEU          443/461         1329.0     ...
# 9              0    ASP,TYR           26/632           76.0     ...
# 10             0       none              NaN            NaN     ...
# 11     369293519    VAL,ILE            5/257           13.0     ...
# 12      11199127    ARG,LEU         865/1001         2594.0     ...
# 13     146020960        GLU          161/337          483.0     ...
# 14      75462174       none              NaN            NaN     ...
# 15             0       none              NaN            NaN     ...
# 16     201714941       none              NaN            NaN     ...
# 17             0        PRO           23/358           69.0     ...
# 18       9418732       none              NaN            NaN     ...
# 19       9418733       none              NaN            NaN     ...
# 20      76119360    ARG,TRP          204/350          610.0     ...
# 21             0       none              NaN            NaN     ...
# 22             0       none              NaN            NaN     ...
# 23             0       none              NaN            NaN     ...
# 24     118180599        GLU          223/577          669.0     ...
# 25             0       none              NaN            NaN     ...
# 26     140210748    THR,LYS          144/215          431.0     ...
# 27     140210748       none              NaN          903.0     ...
# 28             0       none              NaN            NaN     ...
# 29     202019358       none              NaN            NaN     ...
# ...          ...        ...              ...            ...     ...
# 10183          0       none              NaN            NaN     ...
# 10184          0        PHE          159/180          477.0     ...
# 10185          0       none              NaN          713.0     ...
# 10186          0    VAL,LEU        1095/1463         3283.0     ...
# 10187          0       none              NaN            NaN     ...
# 10188          0       none              NaN            NaN     ...
# 10189          0       none              NaN            NaN     ...
# 10190          0       none              NaN            NaN     ...
# 10191          0       none              NaN            NaN     ...
# 10192          0       none              NaN            NaN     ...
# 10193          0       none              NaN            NaN     ...
# 10194  200525472       none              NaN            NaN     ...
# 10195          0       none              NaN            NaN     ...
# 10196          0    LEU,PRO           27/835           80.0     ...
# 10197          0       none              NaN            NaN     ...
# 10198          0    LEU,PRO           35/835          104.0     ...
# 10199          0        PRO        1293/1489         3879.0     ...
# 10200          0       none              NaN            NaN     ...
# 10201          0        PRO        1292/1489         3876.0     ...
# 10202          0       none              NaN            NaN     ...
# 10203          0        PRO        1187/1489         3561.0     ...
# 10204          0       none              NaN            NaN     ...
# 10205          0        PRO        1185/1489         3555.0     ...
# 10206          0       none              NaN            NaN     ...
# 10207          0        SER         424/1744         1272.0     ...
# 10208          0        HIS          790/962         2370.0     ...
# 10209          0        PRO          176/962          528.0     ...
# 10210          0    ARG,PRO          172/962          515.0     ...
# 10211          0       none              NaN            NaN     ...
# 10212          0       none              NaN            NaN     ...
#
#       P1Alt  P1Total  P1_AltFreq P2Ref  P2Alt  P2Total  P2_AltFreq  \
# 0         7       45        0.16    39      5       44        0.11
# 1         2       43        0.05    29      1       30        0.03
# 2         6       23        0.26    19      7       26        0.27
# 3         3       22        0.14    18      7       25        0.28
# 4         6       24        0.25    22      2       24        0.08
# 5         4        7        0.57    17      0       17        0.00
# 6         5       30        0.17    31      3       34        0.09
# 7        32       61        0.52    65      0       65        0.00
# 8        25       42        0.60    48      0       48        0.00
# 9         0       91        0.00    55     54      109        0.50
# 10        0       91        0.00    55     54      109        0.50
# 11       12       21        0.57    26      0       26        0.00
# 12       21       46        0.46    57      0       57        0.00
# 13        0       52        0.00    30     27       57        0.47
# 14        9       76        0.12    58      4       62        0.06
# 15       10       69        0.14    56      3       59        0.05
# 16       11       65        0.17    51      7       58        0.12
# 17        2       38        0.05    45      6       51        0.12
# 18        6       11        0.55     4      4        8        0.50
# 19       14       39        0.36    20     18       38        0.47
# 20        0       25        0.00    21     20       41        0.49
# 21       12       48        0.25    58      9       67        0.13
# 22       12       48        0.25    58      9       67        0.13
# 23       15       42        0.36    48     11       59        0.19
# 24        0       35        0.00    52      0       52        0.00
# 25        3       17        0.18    23      6       29        0.21
# 26        4       29        0.14    30      6       36        0.17
# 27        4       29        0.14    30      6       36        0.17
# 28        4       22        0.18    34      5       39        0.13
# 29        2       23        0.09    32      7       39        0.18
# ...     ...      ...         ...   ...    ...      ...         ...
# 10183     2       15        0.13    35     14       49        0.29
# 10184     0      147        0.00   174      0      174        0.00
# 10185     0      147        0.00   174      0      174        0.00
# 10186     1       22        0.05    40      3       43        0.07
# 10187     3        6        0.50    10      5       15        0.33
# 10188     3        6        0.50    15      2       17        0.12
# 10189     1        6        0.17    14      3       17        0.18
# 10190     2        7        0.29    15      4       19        0.21
# 10191     1       11        0.09    18      1       19        0.05
# 10192     7       28        0.25    70      6       76        0.08
# 10193     0       63        0.00    69     70      139        0.50
# 10194     8       31        0.26    73     11       84        0.13
# 10195     0        1        0.00    24      2       26        0.08
# 10196     0        1        0.00    24      2       26        0.08
# 10197     0        3        0.00    28      4       32        0.13
# 10198     0        3        0.00    28      4       32        0.13
# 10199     0        2        0.00     5      0        5        0.00
# 10200     0        2        0.00     5      0        5        0.00
# 10201     0        2        0.00     4      0        4        0.00
# 10202     0        2        0.00     4      0        4        0.00
# 10203     6       18        0.33    41      6       47        0.13
# 10204     6       18        0.33    41      6       47        0.13
# 10205     5       19        0.26    41     15       56        0.27
# 10206     5       19        0.26    41     15       56        0.27
# 10207     0       22        0.00    58      0       58        0.00
# 10208     0       42        0.00    50     37       87        0.43
# 10209     0        5        0.00     5      1        6        0.17
# 10210     1        7        0.14    12      2       14        0.14
# 10211     0       12        0.00    37      0       37        0.00
# 10212     3       22        0.14    34      7       41        0.17
#
#        Proband_Sample_Name js_cause localization
# 0           8084Trio.final        0            1
# 1           8084Trio.final        0            1
# 2           8084Trio.final        0            1
# 3           8084Trio.final        0            1
# 4           8084Trio.final        0            1
# 5           8084Trio.final        0            1
# 6           8084Trio.final        0            1
# 7           8084Trio.final        0            1
# 8           8084Trio.final        0            1
# 9           8084Trio.final        0            1
# 10          8084Trio.final        0            1
# 11          8084Trio.final        0            1
# 12          8084Trio.final        0            1
# 13          8084Trio.final        0            1
# 14          8084Trio.final        0            1
# 15          8084Trio.final        0            1
# 16          8084Trio.final        0            1
# 17          8084Trio.final        0            0
# 18          8084Trio.final        0            1
# 19          8084Trio.final        0            1
# 20          8084Trio.final        0            1
# 21          8084Trio.final        0            1
# 22          8084Trio.final        0            1
# 23          8084Trio.final        0            1
# 24          8084Trio.final        0            1
# 25          8084Trio.final        0            1
# 26          8084Trio.final        0            1
# 27          8084Trio.final        0            1
# 28          8084Trio.final        0            1
# 29          8084Trio.final        0            1
# ...                    ...      ...          ...
# 10183       8501Trio.final        0            1
# 10184       8501Trio.final        0            1
# 10185       8501Trio.final        0            1
# 10186       8501Trio.final        0            1
# 10187       8501Trio.final        0            1
# 10188       8501Trio.final        0            1
# 10189       8501Trio.final        0            1
# 10190       8501Trio.final        0            1
# 10191       8501Trio.final        0            1
# 10192       8501Trio.final        0            1
# 10193       8501Trio.final        0            1
# 10194       8501Trio.final        0            1
# 10195       8501Trio.final        0            1
# 10196       8501Trio.final        0            1
# 10197       8501Trio.final        0            1
# 10198       8501Trio.final        0            1
# 10199       8501Trio.final        0            1
# 10200       8501Trio.final        0            1
# 10201       8501Trio.final        0            1
# 10202       8501Trio.final        0            1
# 10203       8501Trio.final        0            1
# 10204       8501Trio.final        0            1
# 10205       8501Trio.final        0            1
# 10206       8501Trio.final        0            1
# 10207       8501Trio.final        0            1
# 10208       8501Trio.final        0            1
# 10209       8501Trio.final        0            1
# 10210       8501Trio.final        0            1
# 10211       8501Trio.final        0            1
# 10212       8501Trio.final        0            1
#
# [10213 rows x 42 columns]>

# %%
exomeFiltered = exome.loc[:, ['GERP','CADD_score', 'Dist2Splice','AB', 'P1_AltFreq', 'P2_AltFreq' ,'localization', 'js_cause']]

# %%
exome.shape
# Out:
# (10213, 42)

# %%
exomeLoc = exomeFiltered.loc[:,['GERP','CADD_score', 'Dist2Splice','AB', 'P1_AltFreq', 'P2_AltFreq' , 'localization']]
exomeJS = exomeFiltered.loc[:,['GERP','CADD_score', 'Dist2Splice','AB', 'P1_AltFreq', 'P2_AltFreq' , 'js_cause']]
exomeTest = exomeFiltered.loc[:,['GERP','CADD_score', 'Dist2Splice','AB', 'P1_AltFreq', 'P2_AltFreq' ]]
exomeTest.shape
# Out:
# (10213, 6)

# %%
#PCA portion of the analysis
eigenVariant = PCA()
eigenVariant.fit(exomeTest)

plt.plot(np.cumsum(eigenVariant.explained_variance_ratio_))
plt.xlabel('Components')
plt.ylabel('Cumulative explained variance')
plt.title('Cumulative Explained Variance By Components')
np.cumsum(eigenVariant.explained_variance_ratio_)
# Out:
# array([ 0.99999557,  0.99999936,  1.        ,  1.        ,  1.        ,  1.        ])

# %%
#PC plot colored by js_cause
variants_red = eigenVariant.transform(exomeTest)
plt.scatter(variants_red[:, 0].flatten(),variants_red[:, 1].flatten(), c=exome['js_cause'])
plt.title("PC1 by PC2")
plt.xlabel("PC1")
plt.ylabel("PC2")

# %%
#PC plot colored by localization
import matplotlib.patches as mpatches
variants_red = eigenVariant.transform(exomeTest)
exomeColor = exome['localization'].replace([0,1],['red','blue'])
plt.scatter(variants_red[:, 0].flatten(),variants_red[:, 1].flatten(), c= exomeColor, s=10)
plt.title("PC1 by PC2")
plt.xlabel("PC1")
plt.ylabel("PC2")
classes = ['Cell Body Only','Cilia']
class_colours = ['red','blue']
recs = []
for i in range(0,len(class_colours)):
    recs.append(mpatches.Rectangle((0,0),1,1,fc=class_colours[i]))
plt.legend(recs,classes,loc=4)

# %%
#PC plot with transparent points to shown frequency of points
import matplotlib.patches as mpatches
variants_red = eigenVariant.transform(exomeTest)
exomeColor = exome['js_cause'].replace([0,1],['red','blue'])
plt.scatter(variants_red[:, 0].flatten(),variants_red[:, 1].flatten(), alpha=0.1)
plt.title("PC1 by PC2")
plt.xlabel("PC1")
plt.ylabel("PC2")

# %%
#PC plot with only JS causative variants.
variants_red = eigenVariant.transform(exomeTest)
plt.scatter(variants_red[:, 0].flatten(),variants_red[:, 1].flatten(), exome['js_cause']==1)
plt.title("PC1 by PC2 With Only Known JS Variants Shown")
plt.xlabel("PC1")
plt.ylabel("PC2")

# %%
#PC plot colored by localization including only JS causative variants
import matplotlib.patches as mpatches
variants_red = eigenVariant.transform(exomeTest)
exomeColor = exome['localization'].replace([1,2,3],['red','yellow','black'])
plt.scatter(variants_red[:, 0].flatten(),variants_red[:, 1].flatten(), exome['js_cause']==1, c= exomeColor ) # need to make this work
plt.title("PC1 by PC2")
plt.xlabel("PC1")
plt.ylabel("PC2")
classes = ['Cell Body Only','Cilia Only','Cell body and Cilia']
class_colours = ['red','yellow','black']
recs = []
for i in range(0,len(class_colours)):
    recs.append(mpatches.Rectangle((0,0),1,1,fc=class_colours[i]))
plt.legend(recs,classes,loc=4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\hankc\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(self, arg, alpha)
#     367                     raise ValueError(
# --> 368                             'length of rgba sequence should be either 3 or 4')
#     369             else:
#
# ValueError: length of rgba sequence should be either 3 or 4
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\hankc\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(self, c, alpha)
#     398             # Single value? Put it in an array with a single row.
# --> 399             return np.array([self.to_rgba(c, alpha)], dtype=np.float)
#     400         except ValueError:
#
# C:\Users\hankc\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(self, arg, alpha)
#     375             raise ValueError(
# --> 376                 'to_rgba: Invalid rgba arg "%s"\n%s' % (str(arg), exc))
#     377
#
# ValueError: to_rgba: Invalid rgba arg "0        red
# 1        red
# 2        red
# 3        red
# 4        red
# 5        red
# 6        red
# 7        red
# 8        red
# 9        red
# 10       red
# 11       red
# 12       red
# 13       red
# 14       red
# 15       red
# 16       red
# 17         0
# 18       red
# 19       red
# 20       red
# 21       red
# 22       red
# 23       red
# 24       red
# 25       red
# 26       red
# 27       red
# 28       red
# 29       red
#         ...
# 10183    red
# 10184    red
# 10185    red
# 10186    red
# 10187    red
# 10188    red
# 10189    red
# 10190    red
# 10191    red
# 10192    red
# 10193    red
# 10194    red
# 10195    red
# 10196    red
# 10197    red
# 10198    red
# 10199    red
# 10200    red
# 10201    red
# 10202    red
# 10203    red
# 10204    red
# 10205    red
# 10206    red
# 10207    red
# 10208    red
# 10209    red
# 10210    red
# 10211    red
# 10212    red
# Name: localization, dtype: object"
# length of rgba sequence should be either 3 or 4
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\hankc\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgb(self, arg)
#     321                 raise ValueError(
# --> 322                     'cannot convert argument to rgb sequence')
#     323
#
# ValueError: cannot convert argument to rgb sequence
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\hankc\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(self, arg, alpha)
#     369             else:
# --> 370                 r, g, b = self.to_rgb(arg)
#     371             if alpha is None:
#
# C:\Users\hankc\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgb(self, arg)
#     327             raise ValueError(
# --> 328                 'to_rgb: Invalid rgb arg "%s"\n%s' % (str(arg), exc))
#     329             # Error messages could be improved by handling TypeError
#
# ValueError: to_rgb: Invalid rgb arg "0"
# cannot convert argument to rgb sequence
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-ad5a6b9f9868> in <module>()
#       3 variants_red = eigenVariant.transform(exomeTest)
#       4 exomeColor = exome['localization'].replace([1,2,3],['red','yellow','black'])
# ----> 5 plt.scatter(variants_red[:, 0].flatten(),variants_red[:, 1].flatten(), exome['js_cause']==1, c= exomeColor ) # need to make this work
#       6 plt.title("PC1 by PC2")
#       7 plt.xlabel("PC1")
#
# C:\Users\hankc\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3256                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3257                          linewidths=linewidths, verts=verts,
# -> 3258                          edgecolors=edgecolors, data=data, **kwargs)
#    3259     finally:
#    3260         ax.hold(washold)
#
# C:\Users\hankc\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1816                     warnings.warn(msg % (label_namer, func.__name__),
#    1817                                   RuntimeWarning, stacklevel=2)
# -> 1818             return func(ax, *args, **kwargs)
#    1819         pre_doc = inner.__doc__
#    1820         if pre_doc is None:
#
# C:\Users\hankc\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3864                 offsets=offsets,
#    3865                 transOffset=kwargs.pop('transform', self.transData),
# -> 3866                 alpha=alpha
#    3867                 )
#    3868         collection.set_transform(mtransforms.IdentityTransform())
#
# C:\Users\hankc\Anaconda3\lib\site-packages\matplotlib\collections.py in __init__(self, paths, sizes, **kwargs)
#     829         """
#     830
# --> 831         Collection.__init__(self, **kwargs)
#     832         self.set_paths(paths)
#     833         self.set_sizes(sizes)
#
# C:\Users\hankc\Anaconda3\lib\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     115
#     116         self.set_edgecolor(edgecolors)
# --> 117         self.set_facecolor(facecolors)
#     118         self.set_linewidth(linewidths)
#     119         self.set_linestyle(linestyles)
#
# C:\Users\hankc\Anaconda3\lib\site-packages\matplotlib\collections.py in set_facecolor(self, c)
#     610             c = mpl.rcParams['patch.facecolor']
#     611         self._facecolors_original = c
# --> 612         self._facecolors = mcolors.colorConverter.to_rgba_array(c, self._alpha)
#     613         self.stale = True
#     614
#
# C:\Users\hankc\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(self, c, alpha)
#     420             result = np.zeros((nc, 4), dtype=np.float)
#     421             for i, cc in enumerate(c):
# --> 422                 result[i] = self.to_rgba(cc, alpha)
#     423             return result
#     424
#
# C:\Users\hankc\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(self, arg, alpha)
#     374         except (TypeError, ValueError) as exc:
#     375             raise ValueError(
# --> 376                 'to_rgba: Invalid rgba arg "%s"\n%s' % (str(arg), exc))
#     377
#     378     def to_rgba_array(self, c, alpha=None):
#
# ValueError: to_rgba: Invalid rgba arg "0"
# to_rgb: Invalid rgb arg "0"
# cannot convert argument to rgb sequence

# %%
#LDA with localization data
model = LinearDiscriminantAnalysis()

X = variants_red[:,[0,1]]
y = exome['localization']

model.fit(X, y)

predicted = model.predict(X)

print(predicted)

for loco in set(predicted):
    plt.scatter(X[predicted==loco,0], X[predicted==loco,1], s=10)
plt.title("LDA with PC1 and PC2")
plt.xlabel("LD1")
plt.ylabel("LD2")

# %%
X_new = model.transform(X)

for loco in set(predicted):
    plt.hist(X_new[predicted==loco], bins=np.linspace(-5,5,20))

# %%
#LDA with JS data
model = LinearDiscriminantAnalysis()

X = variants_red[:,[0,1]]
y = exome['js_cause']

model.fit(X, y)

predicted = model.predict(X)

print(predicted)

for JS in set(predicted):
    plt.scatter(X[predicted==JS,0], X[predicted==JS,1], s=10)
plt.title("LDA with PC1 and PC2")
plt.xlabel("LD1")
plt.ylabel("LD2")

# %%
X_new = model.transform(X)

for loco in set(predicted):
    plt.hist(X_new[predicted==loco], bins=np.linspace(-5,5,20))

# %%
sns.pairplot(exomeTest)

# %%
sns.pairplot(exomeLoc, hue = 'localization')

# %%
sns.pairplot(exomeJS, hue = 'js_cause')

# %%
#Do KNN here

# %%
z = exome['localization']
y = exome['localization']

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(4)
model.fit(X, y)

# define a function for fitting model, plotting the points, and 
# visualizing the decision boundary of the classifier
def plot_classifier_regions(model, X, y):
    G = np.unique(y)
    
    markers = ['o', 's', '>', '']
    for c, i in zip(G, range(len(G))):
        plt.plot(X[y==c, 0], 
                 X[y==c, 1], 
                 markers[c])
    
    xlim = [X[:, 0].min()-0.5, X[:, 0].max()+0.5]
    ylim = [X[:, 1].min()-0.5, X[:, 1].max()+0.5]    
    plt.xlim(xlim)
    plt.ylim(ylim)
    
    model.fit(X, y)
    
    # compute and plot boundaries
    h = 0.01
    xx, yy = np.meshgrid(np.arange(xlim[0], xlim[1], h),
                         np.arange(ylim[0], ylim[1], h))
    
    if hasattr(model, 'decision_function'):
        Z = model.decision_function(np.c_[xx.ravel(), yy.ravel()])
    else:
        Z = model.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, cmap='magma', alpha=.8)
    
    return model

# %%
knn_model = plot_classifier_regions(KNeighborsClassifier(2), X, y)

# %%
knn_model = plot_classifier_regions(KNeighborsClassifier(1), X, z)

# %%
# Megan: Creating new testing code with new data file including variants with no parental reads. KNN and SVM. Creating another new datafile with binary column for localization.
# Hank: Logistic regression, look at other classification models and justify classification models. I'll get started on writing the final report.

# %%
# Include logisitic regression here
